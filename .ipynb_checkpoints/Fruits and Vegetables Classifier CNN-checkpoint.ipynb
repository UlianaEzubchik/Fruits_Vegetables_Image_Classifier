# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
# Define the paths for the datasets
data_train_path = 'Fruits_Vegetables/train'
data_test_path = 'Fruits_Vegetables/test'
data_val_path = 'Fruits_Vegetables/validation'

# Define image dimensions
img_width = 180
img_height = 180

# %%
# Load and preprocess the training dataset
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle = True,
    image_size = (img_width, img_height),
    batch_size = 32)

# Get the class names (categories)
data_cat = data_train.class_names
# Out:
# Found 3115 files belonging to 36 classes.

# %%
# Load and preprocess the validation dataset
data_val = tf.keras.utils.image_dataset_from_directory(
    data_val_path,
    shuffle = True,
    image_size = (img_width, img_height),
    batch_size = 32,
    validation_split = False)
# Out:
# Found 351 files belonging to 36 classes.

# %%
# Load and preprocess the test dataset
data_test = tf.keras.utils.image_dataset_from_directory(
    data_test_path,
    shuffle = True,
    image_size = (img_width, img_height),
    batch_size = 32,
    validation_split = False)
# Out:
# Found 359 files belonging to 36 classes.

# %%
# Visualize some samples from the training dataset
plt.figure(figsize=(10,10))
for image, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_cat[labels[i]])
        plt.axis('off')
plt.show()

# %%
# Define the CNN model
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(len(data_cat))
])

# %%
# Compile the model
model.compile(optimizer = 'adam', loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics = ['accuracy'])

# %%
# Train the model
epochs_size = 25
history = model.fit(data_train, validation_data = data_val, epochs = epochs_size, verbose = 1)
# Out:
# Epoch 1/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 39s 371ms/step - accuracy: 0.0450 - loss: 4.5238 - val_accuracy: 0.3191 - val_loss: 2.5029
# Epoch 2/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 34s 346ms/step - accuracy: 0.2486 - loss: 2.6458 - val_accuracy: 0.5527 - val_loss: 1.6996
# Epoch 3/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 36s 362ms/step - accuracy: 0.4029 - loss: 2.0491 - val_accuracy: 0.6838 - val_loss: 1.1513
# Epoch 4/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 34s 345ms/step - accuracy: 0.5924 - loss: 1.4823 - val_accuracy: 0.8348 - val_loss: 0.6937
# Epoch 5/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 34s 342ms/step - accuracy: 0.7279 - loss: 0.9027 - val_accuracy: 0.9031 - val_loss: 0.4728
# Epoch 6/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 36s 363ms/step - accuracy: 0.8368 - loss: 0.5633 - val_accuracy: 0.9288 - val_loss: 0.3608
# Epoch 7/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 36s 362ms/step - accuracy: 0.8932 - loss: 0.3689 - val_accuracy: 0.9487 - val_loss: 0.2864
# Epoch 8/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 37s 379ms/step - accuracy: 0.9557 - loss: 0.1787 - val_accuracy: 0.9459 - val_loss: 0.3655
# Epoch 9/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 33s 340ms/step - accuracy: 0.9633 - loss: 0.1807 - val_accuracy: 0.9487 - val_loss: 0.2561
# Epoch 10/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 33s 337ms/step - accuracy: 0.9700 - loss: 0.1181 - val_accuracy: 0.9544 - val_loss: 0.2684
# Epoch 11/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 33s 337ms/step - accuracy: 0.9738 - loss: 0.1198 - val_accuracy: 0.9516 - val_loss: 0.3271
# Epoch 12/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 33s 334ms/step - accuracy: 0.9806 - loss: 0.0948 - val_accuracy: 0.9573 - val_loss: 0.2928
# Epoch 13/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 33s 334ms/step - accuracy: 0.9718 - loss: 0.1171 - val_accuracy: 0.9516 - val_loss: 0.3595
# Epoch 14/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 33s 333ms/step - accuracy: 0.9786 - loss: 0.0866 - val_accuracy: 0.9487 - val_loss: 0.4402
# Epoch 15/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 34s 341ms/step - accuracy: 0.9846 - loss: 0.0919 - val_accuracy: 0.9459 - val_loss: 0.3300
# Epoch 16/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 34s 341ms/step - accuracy: 0.9815 - loss: 0.0796 - val_accuracy: 0.9573 - val_loss: 0.3752
# Epoch 17/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 34s 343ms/step - accuracy: 0.9798 - loss: 0.0780 - val_accuracy: 0.9573 - val_loss: 0.3480
# Epoch 18/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 33s 337ms/step - accuracy: 0.9806 - loss: 0.0746 - val_accuracy: 0.9544 - val_loss: 0.3495
# Epoch 19/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 33s 337ms/step - accuracy: 0.9907 - loss: 0.0469 - val_accuracy: 0.9573 - val_loss: 0.3351
# Epoch 20/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 33s 339ms/step - accuracy: 0.9878 - loss: 0.0661 - val_accuracy: 0.9544 - val_loss: 0.2866
# Epoch 21/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 33s 336ms/step - accuracy: 0.9741 - loss: 0.1043 - val_accuracy: 0.9544 - val_loss: 0.3337
# Epoch 22/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 33s 333ms/step - accuracy: 0.9769 - loss: 0.0836 - val_accuracy: 0.9516 - val_loss: 0.3250
# Epoch 23/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 33s 337ms/step - accuracy: 0.9759 - loss: 0.1147 - val_accuracy: 0.9487 - val_loss: 0.2955
# Epoch 24/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 33s 340ms/step - accuracy: 0.9789 - loss: 0.0888 - val_accuracy: 0.9630 - val_loss: 0.2786
# Epoch 25/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 35s 350ms/step - accuracy: 0.9866 - loss: 0.0584 - val_accuracy: 0.9544 - val_loss: 0.2965

# %%
# Plot the training history
epochs_range = range(epochs_size)
plt.figure(figsize = (8, 8))
plt.subplot(1,2,1)
plt.plot(epochs_range, history.history['accuracy'], label = 'Training accuracy')
plt.plot(epochs_range, history.history['val_accuracy'], label = 'Validation accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range, history.history['loss'], label = 'Training loss')
plt.plot(epochs_range, history.history['val_loss'], label = 'Validation loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
# Save the model
model.save('Fruits and Vegetable Classifier.keras')
